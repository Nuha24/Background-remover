# %%
pip install rembg

# %%
# Install the required dependencies
# !pip install rembg onnxruntime
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 63.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.6 MB/s eta 0:00:00
# ...

# %%
import os
from PIL import Image
import numpy as np
import io
import rembg
from google.colab import files

def remove_background_from_image(input_path, output_path):
    with open(input_path, "rb") as input_file:
        input_data = input_file.read()
        output_data = rembg.remove(input_data)

    # Convert the output data to a NumPy array
    output_array = np.frombuffer(output_data, dtype=np.uint8)

    # Decode the array into an image
    output_image = Image.open(io.BytesIO(output_array))

    # Convert the image to RGBA if it's not already
    if output_image.mode != 'RGBA':
        output_image = output_image.convert('RGBA')

    # Create a black background image
    black_background = Image.new('RGBA', output_image.size, (0, 0, 0, 255))

    # Composite the images, using the alpha channel of the output image as a mask
    result = Image.alpha_composite(black_background, output_image)

    # Save the result to the output path
    result.save(output_path, format='PNG')
    print(f"Processed image saved to: {output_path}")

if __name__ == "__main__":
    # Step 1: Upload an image
    print("Please upload an image file:")
    uploaded = files.upload()

    if not uploaded:
        print("No file uploaded. Exiting.")
    else:
        # Get the uploaded file path
        input_file_path = next(iter(uploaded))  # Get the first file name
        output_file_path = "processed_image.png"  # Set the output file name

        # Step 2: Process the uploaded image
        remove_background_from_image(input_file_path, output_file_path)

        # Step 3: Allow the user to download the processed image
        print("Processing complete. Download the processed image below:")
        files.download(output_file_path)
# Out:
# Please upload an image file:
#      <input type="file" id="files-be69b6c4-8a7d-4960-8bc4-d5b51ba1076c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be69b6c4-8a7d-4960-8bc4-d5b51ba1076c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
